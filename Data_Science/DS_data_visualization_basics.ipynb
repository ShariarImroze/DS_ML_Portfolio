# %% [markdown]
# A basic implementaion of seaborn library.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Analysis of FIFA dataset.

# %%
fifa_filepath = 'assets\DS_csv_files\FIFA.csv'

fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates =True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 fifa_filepath = 'assets\DS_csv_files\FIFA.csv'
# ----> 3 fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates =True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...

# %%
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
plt.figure(figsize=(20,10))

sns.lineplot(data=fifa_data)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Analysis of daily streams on the the music streaming service Spotify.

# %%
spotify_filepath = 'assets/csv_files/spotify.csv'

spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates = True)

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data = spotify_data.dropna()

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-04-07      13042637  6533680.0                 9736931.0  8055220.0
# 2017-04-08      12815920  6660608.0                 9334494.0  7280150.0
# 2017-04-09      11291392  5683746.0                 8077875.0  6396104.0
# 2017-04-10      11819128  5762588.0                 8678774.0  7162611.0
# 2017-04-11      11736951  5877897.0                 8591469.0  7468021.0
#
#             Unforgettable
# Date
# 2017-04-07       317011.0
# 2017-04-08       308838.0
# 2017-04-09       756145.0
# 2017-04-10       954504.0
# 2017-04-11       953037.0

# %%
plt.figure(figsize=(20,10))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data)
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %%
plt.figure(figsize=(20,10))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")
sns.lineplot(data=spotify_data['Despacito'],label="Despacito")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# Analysis of Flight Data

# %%
flight_filepath = 'assets\csv_files\delays_flight.csv'

#check by renaming to flight_delays

flight_data = pd.read_csv(flight_filepath, index_col="Month")

# %%
flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize=(20,10))

plt.title("Average Arrival Delay for Sprit Airlines Flights (Monthly)")

sns.barplot(x=flight_data.index, y=flight_data['NK'])

plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
plt.figure(figsize=(20,10))

plt.title("Average Arrival Delay for Each Airline (Monthly)")

sns.heatmap(data=flight_data, annot=True)

plt.xlabel("Airline")
# Out:
# Text(0.5, 80.7222222222222, 'Airline')

# %% [markdown]
# Analysis of Cancer dataset.

# %%
insurance_filepath = "assets/csv_files/insurance.csv"

insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize=(20,10))
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize=(20,10))
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %%
plt.figure(figsize=(10,10))
color_palette = {'yes': 'red', 'no': 'green'}
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'],palette=color_palette)
# Out:
# C:\Users\shari\AppData\Local\Temp\ipykernel_8096\3069379067.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'],palette=color_palette)
# <Axes: xlabel='smoker', ylabel='charges'>
# C:\Users\shari\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3544: UserWarning: 10.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Analysis of Irish dataset.

# %%
iris_filepath = "assets/csv_files/iris.csv"
iris_data = pd.read_csv(iris_filepath, index_col="Id")

# %%
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
plt.figure(figsize=(8,5))
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# C:\Users\shari\AppData\Local\Temp\ipykernel_8096\3071897931.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
plt.figure(figsize=(9,5))
sns.set_style("dark")
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %%
plt.figure(figsize=(9,5))
plt.title("Histogram of Petal Lengths, by Species")
sns.set_style("ticks")
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')
# Out:
# <Axes: title={'center': 'Histogram of Petal Lengths, by Species'}, xlabel='Petal Length (cm)', ylabel='Count'>

# %%
plt.figure(figsize=(9,5))
plt.title("Distribution of Petal Lengths, by Species")
sns.set_style("ticks")
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# Out:
# C:\Users\shari\AppData\Local\Temp\ipykernel_8096\2491414609.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# <Axes: title={'center': 'Distribution of Petal Lengths, by Species'}, xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"
